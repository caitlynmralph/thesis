# %% [markdown]
# # spotify api
# ## caitlyn ralph, msII thesis, parsons MSDV
# ### <a href="https://docs.google.com/document/d/1yM7jbl-SWVWB8geDjit5u7G5zIE_AXSR7i7kT6s5mnA/edit">documentation</a>

# %% [markdown]
# indie

# %%
# %env SPOTIPY_CLIENT_ID=cfc4ee6572e04e8cac87b0d93270e647
# %env SPOTIPY_CLIENT_SECRET=23128cd24b15489ba1841c8b192bf589

import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

sp = spotipy.Spotify(client_credentials_manager=SpotifyClientCredentials())

queries = ['genre:"indie pop" year:2006-2020',
'genre:"indietronica" year:2006-2020',
'genre:"indie rock" year:2006-2020',
'genre:"indie poptimism" year:2006-2020',
'genre:"indie folk" year:2006-2020',
'genre:"indie r&b" year:2006-2020',
'genre:"indie soul" year:2006-2020',
'genre:"la indie" year:2006-2020',
'genre:"indie anthem-folk" year:2006-2020',
'genre:"indiecoustica" year:2006-2020',
'genre:"indie pop rap" year:2006-2020',
'genre:"indie garage rock" year:2006-2020',
'genre:"indie cafe pop" year:2006-2020',
'genre:"indie electropop" year:2006-2020',
'genre:"sheffield indie" year:2006-2020',
'genre:"english indie rock" year:2006-2020',
'genre:"indie jazz" year:2006-2020',
'genre:"k-indie" year:2006-2020',
'genre:"oxford indie" year:2006-2020',
'genre:"indie surf" year:2006-2020',
'genre:"indie punk" year:2006-2020',
'genre:"christian indie" year:2006-2020',
'genre:"british indie rock" year:2006-2020',
'genre:"brighton indie" year:2006-2020',
'genre:"indie game soundtrack" year:2006-2020',
'genre:"liverpool indie" year:2006-2020',
'genre:"indie rockism" year:2006-2020',
'genre:"scottish indie" year:2006-2020',
'genre:"chihuahua indie" year:2006-2020',
'genre:"northern irish indie" year:2006-2020',
'genre:"scottish indie rock" year:2006-2020',
'genre:"nottingham indie" year:2006-2020',
'genre:"leicester indie" year:2006-2020',
'genre:"channel islands indie" year:2006-2020',
'genre:"north east england indie" year:2006-2020',
'genre:"indie dream pop" year:2006-2020',
'genre:"manchester indie" year:2006-2020',
'genre:"glasgow indie" year:2006-2020',
'genre:"indie extremena" year:2006-2020',
'genre:"indie psych-pop" year:2006-2020',
'genre:"bristol indie" year:2006-2020',
'genre:"reading indie" year:2006-2020',
'genre:"birmingham indie" year:2006-2020',
'genre:"cambridgeshire indie" year:2006-2020',
'genre:"london indie" year:2006-2020',
'genre:"york indie" year:2006-2020',
'genre:"irish indie" year:2006-2020',
'genre:"welsh indie" year:2006-2020',
'genre:"kent indie" year:2006-2020',
'genre:"leeds indie" year:2006-2020',
'genre:"bath indie" year:2006-2020',
'genre:"devon indie" year:2006-2020',
'genre:"newcastle indie" year:2006-2020',
'genre:"irish indie rock" year:2006-2020',
'genre:"kindie rock" year:2006-2020',
'genre:"southampton indie" year:2006-2020',
'genre:"warrington indie" year:2006-2020',
'genre:"cork indie" year:2006-2020',
'genre:"dublin indie" year:2006-2020',
'genre:"indie emo" year:2006-2020',
'genre:"indie electronica" year:2006-2020',
'genre:"east anglia indie" year:2006-2020',
'genre:"edinburgh indie" year:2006-2020',
'genre:"essex indie" year:2006-2020',
'genre:"calgary indie" year:2006-2020',
'genre:"west yorkshire indie" year:2006-2020',
'genre:"isle of wight indie" year:2006-2020',
'genre:"derby indie" year:2006-2020',
'genre:"indie singer-songwriter" year:2006-2020',
'genre:"lancashire indie" year:2006-2020',
'genre:"derry indie" year:2006-2020',
'genre:"newcastle nsw indie" year:2006-2020',
'genre:"indie shoegaze" year:2006-2020',
'genre:"cornwall indie" year:2006-2020',
'genre:"swansea indie" year:2006-2020',
'genre:"dundee indie" year:2006-2020',
'genre:"limerick indie" year:2006-2020',
'genre:"experimental indie" year:2006-2020',
'genre:"coventry indie" year:2006-2020',
'genre:"cardiff indie" year:2006-2020',
'genre:"indie fuzzpop" year:2006-2020',
'genre:"deep indie pop" year:2006-2020',
'genre:"scottish indie folk" year:2006-2020',
'genre:"indie pop rock" year:2006-2020',
'genre:"isle of man indie" year:2006-2020',
'genre:"aberdeen indie" year:2006-2020',
'genre:"portsmouth indie" year:2006-2020',
'genre:"deep indie singer-songwriter" year:2006-2020',
'genre:"northamptonshire indie" year:2006-2020',
'genre:"indie psychedelic rock" year:2006-2020',
'genre:"hull indie" year:2006-2020',
'genre:"belfast indie" year:2006-2020',
'genre:"normal indie" year:2006-2020',
'genre:"galway indie" year:2006-2020',
'genre:"deep indie rock" year:2006-2020',
'genre:"bury st edmunds indie" year:2006-2020',
'genre:"indie emo rock" year:2006-2020',
'genre:"twee indie pop" year:2006-2020']

off=0

artists={}

for query in queries:
    while off<=1950:
        results = sp.search(q=query, type='artist', market='GB', offset=off)
        for idx, artist in enumerate(results['artists']['items']):
            artistID=artist['uri']
            artistName=artist['name']
            artistPopularity=artist['popularity']
            if artistID not in artists.keys(): 
                artists[artistID] = str(artistName) + "," + str(artistPopularity)
        off=off+50
        print(off)
    off=0
# Out:
# env: SPOTIPY_CLIENT_ID=cfc4ee6572e04e8cac87b0d93270e647
# env: SPOTIPY_CLIENT_SECRET=23128cd24b15489ba1841c8b192bf589
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# 1000
# 1050
# 1100
# 1150
# 1200
# 1250
# 1300
# 1350
# 1400
# 1450
# 1500
# 1550
# 1600
# 1650
# 1700
# 1750
# 1800
# 1850
# 1900
# 1950
# 2000
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# 1000
# 1050
# 1100
# 1150
# 1200
# 1250
# 1300
# 1350
# 1400
# 1450
# 1500
# 1550
# 1600
# 1650
# 1700
# 1750
# 1800
# 1850
# 1900
# 1950
# 2000
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# 1000
# 1050
# 1100
# 1150
# 1200
# 1250
# 1300
# 1350
# 1400
# 1450
# 1500
# 1550
# 1600
# 1650
# 1700
# 1750
# 1800
# 1850
# 1900
# 1950
# 2000
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# ...

# %%
import pandas as pd

df = pd.DataFrame.from_dict(artists, orient="index")
df.to_csv("artists-indie.csv")

# %% [markdown]
# alt

# %%
# %env SPOTIPY_CLIENT_ID=cfc4ee6572e04e8cac87b0d93270e647
# %env SPOTIPY_CLIENT_SECRET=23128cd24b15489ba1841c8b192bf589

import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

sp = spotipy.Spotify(client_credentials_manager=SpotifyClientCredentials())

queries = ['genre:"alternative metal" year:2006-2020',
'genre:"alternative rock" year:2006-2020',
'genre:"alternative r&b" year:2006-2020',
'genre:"modern alternative rock" year:2006-2020',
'genre:"alternative dance" year:2006-2020',
'genre:"christian alternative rock" year:2006-2020',
'genre:"alternative hip hop" year:2006-2020',
'genre:"alternative country" year:2006-2020',
'genre:"alternative emo" year:2006-2020',
'genre:"uk alternative hip hop" year:2006-2020',
'genre:"uk alternative pop" year:2006-2020',
'genre:"alternative pop rock" year:2006-2020',
'genre:"alternative pop" year:2006-2020',
'genre:"british alternative rock" year:2006-2020',
'genre:"hard alternative" year:2006-2020',
'genre:"alternative roots rock" year:2006-2020',
'genre:"heavy alternative" year:2006-2020',
'genre:"gothic alternative" year:2006-2020',
'genre:"progressive alternative" year:2006-2020',
'genre:"alternative metalcore" year:2006-2020',
'genre:"alternative hardcore" year:2006-2020',]

off=0

artists={}

for query in queries:
    while off<=1950:
        results = sp.search(q=query, type='artist', market='GB', offset=off)
        for idx, artist in enumerate(results['artists']['items']):
            artistID=artist['uri']
            artistName=artist['name']
            artistPopularity=artist['popularity']
            if artistID not in artists.keys(): 
                artists[artistID] = str(artistName) + "," + str(artistPopularity)
        off=off+50
        print(off)
    off=0
# Out:
# env: SPOTIPY_CLIENT_ID=cfc4ee6572e04e8cac87b0d93270e647
# env: SPOTIPY_CLIENT_SECRET=23128cd24b15489ba1841c8b192bf589
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# 1000
# 1050
# 1100
# 1150
# 1200
# 1250
# 1300
# 1350
# 1400
# 1450
# 1500
# 1550
# 1600
# 1650
# 1700
# 1750
# 1800
# 1850
# 1900
# 1950
# 2000
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# 1000
# 1050
# 1100
# 1150
# 1200
# 1250
# 1300
# 1350
# 1400
# 1450
# 1500
# 1550
# 1600
# 1650
# 1700
# 1750
# 1800
# 1850
# 1900
# 1950
# 2000
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# 1000
# 1050
# 1100
# 1150
# 1200
# 1250
# 1300
# 1350
# 1400
# 1450
# 1500
# 1550
# 1600
# 1650
# 1700
# 1750
# 1800
# 1850
# 1900
# 1950
# 2000
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# ...

# %%
import pandas as pd

df = pd.DataFrame.from_dict(artists, orient="index")
df.to_csv("artists-alt.csv")
